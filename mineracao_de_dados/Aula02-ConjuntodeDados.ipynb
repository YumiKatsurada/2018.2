# %% [markdown]
# # Aula 2 - Conjunto dos dados
# Este notebook contém os exemplos de aula, aplicando sobre o conjunto de dados Iris.

# %%
import numpy as np
import pandas as pd

# Localização do arquivo
filepath = 'data/Iris_Data.csv'
# Importando os dados
data = pd.read_csv(filepath)
# Imprimindo as cinco primeras linhas
print(data.iloc[:5])
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Calculando a área da sépala
data['sepal_area'] = data.sepal_length * data.sepal_width

# Imprimindo algumas linhas e colunas
print(data.iloc[:5, -3:])
# Out:
#    petal_width      species  sepal_area
# 0          0.2  Iris-setosa       17.85
# 1          0.2  Iris-setosa       14.70
# 2          0.2  Iris-setosa       15.04
# 3          0.2  Iris-setosa       14.26
# 4          0.2  Iris-setosa       18.00

# %%
# Usando o método size com DataFrame 
# Para séries, usar o método .value_counts
group_sizes = (data
              .groupby('species')
              .size())
print(group_sizes)
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
# Média sobre o DataFrame
print(data.mean())
# Média sobre série
print(data.petal_length.median())
# Moda calculada sobre série
print(data.petal_length.mode())
# Out:
# sepal_length     5.843333
# sepal_width      3.054000
# petal_length     3.758667
# petal_width      1.198667
# sepal_area      17.806533
# dtype: float64
# 4.35
# 0    1.5
# dtype: float64

# %%
# Desvio padrão, variância, e desvio padrão da média 
print(data.petal_length.std(), data.petal_length.var(), data.petal_length.sem())
# Retorna quartis
print(data.quantile(0))
# Out:
# 1.7644204199522617 3.1131794183445156 0.1440643240210084
# sepal_length     4.3
# sepal_width      2.0
# petal_length     1.0
# petal_width      0.1
# sepal_area      10.0
# Name: 0, dtype: float64

# %%
#Análise e descrição dos dados
print(data.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width  sepal_area
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667   17.806533
# std        0.828066     0.433594      1.764420     0.763161    3.368693
# min        4.300000     2.000000      1.000000     0.100000   10.000000
# 25%        5.100000     2.800000      1.600000     0.300000   15.645000
# 50%        5.800000     3.000000      4.350000     1.300000   17.660000
# 75%        6.400000     3.300000      5.100000     1.800000   20.325000
# max        7.900000     4.400000      6.900000     2.500000   30.020000

# %%
# Análise da covariância entre os atributos Iris
print(data.cov())
# Out:
#               sepal_length  sepal_width  petal_length  petal_width  sepal_area
# sepal_length      0.685694    -0.039268      1.273682     0.516904    1.906238
# sepal_width      -0.039268     0.188004     -0.321713    -0.117981    0.942732
# petal_length      1.273682    -0.321713      3.113179     1.296387    2.178896
# petal_width       0.516904    -0.117981      1.296387     0.582414    0.965009
# sepal_area        1.906238     0.942732      2.178896     0.965009   11.348090

# %%
#Análise da correlação entre os atributos
print(data.corr())
# Out:
#               sepal_length  sepal_width  petal_length  petal_width  sepal_area
# sepal_length      1.000000    -0.109369      0.871754     0.817954    0.683362
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544    0.645421
# petal_length      0.871754    -0.420516      1.000000     0.962757    0.366584
# petal_width       0.817954    -0.356544      0.962757     1.000000    0.375365
# sepal_area        0.683362     0.645421      0.366584     0.375365    1.000000

# %% [markdown]
# ## Explorando os dados

# %%
import matplotlib.pyplot as plt
# Comparando comprimento com largura da sépala
plt.plot(data.sepal_length, data.sepal_width,ls='', marker='o')

# %%
# Comparando comprimento com largura da sépala e pétala
plt.plot(data.sepal_length, data.sepal_width, ls ='', marker='o', label='sepal')
plt.plot(data.petal_length, data.petal_width, ls ='', marker='o', label='petal')

# %%
# Comparando comprimento com largura da sépala e pétala em três dimensões
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
plt.plot(data.sepal_length, data.sepal_width,ls ='', marker='o', label='sepal')
plt.plot(data.petal_length, data.petal_width,ls ='', marker='+', label='petal')
ax.set_xlabel('Comprimento')
ax.set_ylabel('Largura')
plt.show()

# %%
# Histograma com largura de sépala
plt.hist(data.sepal_width, bins=25)
# Out:
# (array([ 1.,  0.,  3.,  4.,  3.,  8.,  5.,  9., 14., 10., 26., 12., 13.,
#          6., 12.,  6.,  3.,  3.,  6.,  2.,  1.,  1.,  1.,  0.,  1.]),
#  array([2.   , 2.096, 2.192, 2.288, 2.384, 2.48 , 2.576, 2.672, 2.768,
#         2.864, 2.96 , 3.056, 3.152, 3.248, 3.344, 3.44 , 3.536, 3.632,
#         3.728, 3.824, 3.92 , 4.016, 4.112, 4.208, 4.304, 4.4  ]),
#  <a list of 25 Patch objects>)

# %%
ig, ax = plt.subplots()
ax.barh(np.arange(10), data.sepal_length.iloc[:10])
ax.set(xlabel='Centímetros', ylabel='Número',    
       title='Comprimento de Sépala')
# Out:
# [Text(0,0.5,'Número'),
#  Text(0.5,0,'Centímetros'),
#  Text(0.5,1,'Comprimento de Sépala')]

# %%
#Fazendo histograma 3D na marra
#Precisa de ajustes e melhoramentos, se alguém puder fazê-lo me avise

petal = np.zeros(9,dtype=int)
length_range = max(data.petal_length) - min(data.petal_length)
width_range = max(data.petal_width) - min(data.petal_width)

for i in range(data.shape[0]):
    if data.petal_length[i] < min(data.petal_length) + length_range*1/3 :
        if data.petal_width[i] < min(data.petal_width) + width_range*1/3:
            petal[0] += 1
        elif data.petal_width[i] < min(data.petal_width) + width_range*2/3:
            petal[1] += 1
        elif data.petal_width[i] < min(data.petal_width) + width_range:
            petal[2] += 1
    elif data.petal_length[i] < min(data.petal_length) + length_range*2/3 :
            if data.petal_width[i] < min(data.petal_width) + width_range*1/3:
                petal[3] += 1
            elif data.petal_width[i] < min(data.petal_width) + width_range*2/3:
                petal[4] += 1
            elif data.petal_width[i] < min(data.petal_width) + width_range:
                petal[5] += 1
    elif data.petal_length[i] < min(data.petal_length) + length_range :
            if data.petal_width[i] < min(data.petal_width) + width_range*1/3:
                petal[6] += 1
            elif data.petal_width[i] < min(data.petal_width) + width_range*2/3:
                petal[7] += 1
            elif data.petal_width[i] < min(data.petal_width) + width_range:
                petal[8] += 1
  
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
xpos = np.zeros(9)
ypos = np.zeros(9)

xpos[0] = min(data.petal_length)
xpos[3] = min(data.petal_length)
xpos[6] = min(data.petal_length)
xpos[1] = min(data.petal_length) + length_range*1/3
xpos[4] = min(data.petal_length) + length_range*1/3
xpos[7] = min(data.petal_length) + length_range*1/3
xpos[2] = min(data.petal_length) + length_range*2/3
xpos[5] = min(data.petal_length) + length_range*2/3
xpos[8] = min(data.petal_length) + length_range*2/3
ypos[0] = min(data.petal_width)
ypos[3] = min(data.petal_width)
ypos[6] = min(data.petal_width)
ypos[1] = min(data.petal_width) + width_range*1/3
ypos[4] = min(data.petal_width) + width_range*1/3
ypos[7] = min(data.petal_width) + width_range*1/3
ypos[2] = min(data.petal_width) + width_range*2/3
ypos[5] = min(data.petal_width) + width_range*2/3
ypos[8] = min(data.petal_width) + width_range*2/3
zpos = [0,0,0,0,0,0,0,0,0]
dx = [length_range*1/3]*9
dy = [width_range*1/3]*9
dz = petal

ax1.bar3d(xpos, ypos, zpos, dx, dy, dz, color='#00ceaa')
plt.show()

# %%
#Gráfico de setores sobre Iris
labels = data['species'].unique()
sizes = data.groupby('species').size()
colors = ['gold', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0) 
plt.pie(sizes, explode=explode, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fab419c2390>,
# ...
#  [Text(-1.12763,-0.410424,'Iris-setosa'),
#   Text(0.842649,-0.707066,'Iris-versicolor'),
#   Text(0.191013,1.08329,'Iris-virginica')],
#  [Text(-0.657785,-0.239414,'33.3%'),
#   Text(0.459627,-0.385673,'33.3%'),
#   Text(0.104189,0.590885,'33.3%')])

# %%
#Gráfico de densidade para o atributo comprimento de sépala
import seaborn as sns
sns.FacetGrid(data, hue="species", size=5).map(sns.kdeplot, "sepal_length").add_legend()

# %%
#Gŕaficos de dispersão
# Importando os dados novamente
data = pd.read_csv(filepath)
sns.pairplot(data,hue='species',size=3)

# %%
#Boxplot usando seaborn
sns.boxplot(x="species", y="sepal_length", data=data)

# %%
ax = sns.boxplot(x="species", y="sepal_length", data=data)
ax = sns.stripplot(x="species", y="sepal_length", data=data, jitter=True, edgecolor="black")

# %%
#Usando violin plot do SeaBorn 
sns.violinplot(x="species", y="sepal_length", data=data, size=6)

# %%
#Aplicando mapa de calor para a correlação entre atributos Iris
corr = data.corr()
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)

# %%
#Aplicando agrupamento no conjunto e retornando dendrograma 
iris = sns.load_dataset("iris")
species = iris.pop("species")
g = sns.clustermap(iris)

# %%
#Dendrograma de correlações entre os objetos
sns.clustermap(iris, metric="correlation")

# %%
#Aplicando coordenadas paralelas
pd.plotting.parallel_coordinates(data, "species")

# %%
#Plotando curvas de Andrews
pd.plotting.andrews_curves(data, "species")

# %%
#Usando RadViz para dados Iris
pd.plotting.radviz(data, "species")

# %%
# Categorias e número de variáveis
categories=list(data)[0:4]
N = len(categories)
 
# Impressão do primeiro padrão do conjunto Iris
# É preciso repetir o primeiro valor para forma gráfico circular
values=data.loc[0].drop('species').values.flatten().tolist()
values += values[:1]
values
 
# Monta o ângulo de cada exigo no gráfico 
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Inicialia o gráfico
ax = plt.subplot(111, polar=True)
 
# Desenha um eixo por variável e insere os rótulos 
plt.xticks(angles[:-1], categories, color='grey', size=8)
 
# Desenha os rótulos em Y
ax.set_rlabel_position(0)
plt.yticks([2,4,6], ["2","4","6"], color="grey", size=7)
plt.ylim(0,8)
 
# Plota os dados
ax.plot(angles, values, linewidth=1, linestyle='solid')
 
# Preenche a área interna
ax.fill(angles, values, 'b', alpha=0.1)

# %%
# Categorias e número de variáveis
categories=list(data)[0:4]
N = len(categories)
 
# Monta o ângulo de cada exigo no gráfico 
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Inicializa gráfico
ax = plt.subplot(111, polar=True)
 
# Primeiro eixo no topo para visualização
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Desenha um eixo por variável e rotula
plt.xticks(angles[:-1], categories)
 
# Desenha rótulos de no eixo Y
ax.set_rlabel_position(0)
plt.yticks([2,4,6], ["2","4","6"], color="grey", size=7)
plt.ylim(0,8)
  
# Plotando gráfico 1, exemplo número 5
values=data.loc[5].drop('species').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Setosa")
ax.fill(angles, values, 'b', alpha=0.1)
 
# Plotando gráfico 2, exemplo número 105
values=data.loc[105].drop('species').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Virginica")
ax.fill(angles, values, 'r', alpha=0.1)
 
# Coloca legenda
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
